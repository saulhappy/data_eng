# %%
import boto3
import pandas as pd
from io import StringIO

# %%
s3 = boto3.resource('s3')
bucket = s3.Bucket('deutsche-boerse-xetra-pds')

# %%
bucket_obj = bucket.objects.filter(Prefix = '2021-03-15')
objects = [obj for obj in bucket_obj]
objects
# Out:
# [s3.ObjectSummary(bucket_name='deutsche-boerse-xetra-pds', key='2021-03-15/2021-03-15_BINS_XETR00.csv'),
#  s3.ObjectSummary(bucket_name='deutsche-boerse-xetra-pds', key='2021-03-15/2021-03-15_BINS_XETR01.csv'),
#  s3.ObjectSummary(bucket_name='deutsche-boerse-xetra-pds', key='2021-03-15/2021-03-15_BINS_XETR02.csv'),
#  s3.ObjectSummary(bucket_name='deutsche-boerse-xetra-pds', key='2021-03-15/2021-03-15_BINS_XETR03.csv'),
#  s3.ObjectSummary(bucket_name='deutsche-boerse-xetra-pds', key='2021-03-15/2021-03-15_BINS_XETR04.csv'),
#  s3.ObjectSummary(bucket_name='deutsche-boerse-xetra-pds', key='2021-03-15/2021-03-15_BINS_XETR05.csv'),
#  s3.ObjectSummary(bucket_name='deutsche-boerse-xetra-pds', key='2021-03-15/2021-03-15_BINS_XETR06.csv'),
#  s3.ObjectSummary(bucket_name='deutsche-boerse-xetra-pds', key='2021-03-15/2021-03-15_BINS_XETR07.csv'),
#  s3.ObjectSummary(bucket_name='deutsche-boerse-xetra-pds', key='2021-03-15/2021-03-15_BINS_XETR08.csv'),
#  s3.ObjectSummary(bucket_name='deutsche-boerse-xetra-pds', key='2021-03-15/2021-03-15_BINS_XETR09.csv'),
#  s3.ObjectSummary(bucket_name='deutsche-boerse-xetra-pds', key='2021-03-15/2021-03-15_BINS_XETR10.csv'),
#  s3.ObjectSummary(bucket_name='deutsche-boerse-xetra-pds', key='2021-03-15/2021-03-15_BINS_XETR11.csv'),
#  s3.ObjectSummary(bucket_name='deutsche-boerse-xetra-pds', key='2021-03-15/2021-03-15_BINS_XETR12.csv'),
#  s3.ObjectSummary(bucket_name='deutsche-boerse-xetra-pds', key='2021-03-15/2021-03-15_BINS_XETR13.csv'),
#  s3.ObjectSummary(bucket_name='deutsche-boerse-xetra-pds', key='2021-03-15/2021-03-15_BINS_XETR14.csv'),
#  s3.ObjectSummary(bucket_name='deutsche-boerse-xetra-pds', key='2021-03-15/2021-03-15_BINS_XETR15.csv'),
#  s3.ObjectSummary(bucket_name='deutsche-boerse-xetra-pds', key='2021-03-15/2021-03-15_BINS_XETR16.csv'),
#  s3.ObjectSummary(bucket_name='deutsche-boerse-xetra-pds', key='2021-03-15/2021-03-15_BINS_XETR17.csv'),
#  s3.ObjectSummary(bucket_name='deutsche-boerse-xetra-pds', key='2021-03-15/2021-03-15_BINS_XETR18.csv'),
#  s3.ObjectSummary(bucket_name='deutsche-boerse-xetra-pds', key='2021-03-15/2021-03-15_BINS_XETR19.csv'),
#  s3.ObjectSummary(bucket_name='deutsche-boerse-xetra-pds', key='2021-03-15/2021-03-15_BINS_XETR20.csv'),
#  s3.ObjectSummary(bucket_name='deutsche-boerse-xetra-pds', key='2021-03-15/2021-03-15_BINS_XETR21.csv'),
#  s3.ObjectSummary(bucket_name='deutsche-boerse-xetra-pds', key='2021-03-15/2021-03-15_BINS_XETR22.csv'),
#  s3.ObjectSummary(bucket_name='deutsche-boerse-xetra-pds', key='2021-03-15/2021-03-15_BINS_XETR23.csv')]

# %%
csv_obj = bucket.Object(key='2021-03-15/2021-03-15_BINS_XETR15.csv').get().get('Body').read().decode('utf-8')
csv_obj
# Out:
# 'ISIN,Mnemonic,SecurityDesc,SecurityType,Currency,SecurityID,Date,Time,StartPrice,MaxPrice,MinPrice,EndPrice,TradedVolume,NumberOfTrades\nCA0679011084,ABR,BARRICK GOLD CORP.,Common stock,EUR,2504196,2021-03-15,15:00,17.06,17.06,17.06,17.06,2000,1\nDE000A0BVU28,OSP2,USU SOFTWARE AG,Common stock,EUR,2504280,2021-03-15,15:00,26.6,26.6,26.6,26.6,70,1\nDE000A0D6554,NDX1,NORDEX SE O.N.,Common stock,EUR,2504290,2021-03-15,15:00,22.12,22.12,22.12,22.12,119,1\nDE000A0D9PT0,MTX,MTU AERO ENGINES NA O.N.,Common stock,EUR,2504297,2021-03-15,15:00,204.3,204.4,204.3,204.4,98,4\nDE000A0F5UJ7,EXV1,IS.S.EU.600 BANK.U.ETF A.,ETF,EUR,2504306,2021-03-15,15:00,12.656,12.662,12.656,12.662,5,3\nDE000A0F5UK5,EXV6,IS.S.E.600 BA.RE.U.ETF A.,ETF,EUR,2504307,2021-03-15,15:00,58.41,58.41,58.41,58.41,11,1\nDE000A0HN5C6,DWNI,DEUTSCHE WOHNEN SE INH,Common stock,EUR,2504314,2021-03-15,15:00,38.87,38.87,38.87,38.87,242,2\nDE000A0JC8S7,D6H,DATAGROUP SE  INH. O.N.,Common stock,EUR,2504338,2021-03-15,15:00,61.3,61.3,61.2,61.2,313,5\nDE000A0JM2M1,B7E,BLUE CAP             O.N.,Common stock,EUR,2504344,2021-03-15,15:00,24.2,24.2,24.2,24.2,39,1\nDE000A0JQ5U3,M5Z,MANZ AG,Common stock,EUR,2504345,2021-03-15,15:00,42.5,42.5,42.3,42.3,168,3\nDE000A0KRJ44,OD7M,WITR COM.SEC.DZ06/UN.NICK,ETC,EUR,2504364,2021-03-15,15:00,12.75,12.75,12.75,12.75,200,1\nDE000A0KRJ69,OD7P,WITR COM.SEC.DZ06/UN.SOYO,ETC,EUR,2504365,2021-03-15,15:00,4.6988,4.6988,4.6988,4.6988,138,1\nDE000A0KRKC6,OD7V,WITR COM.SEC.DZ06/UN.I
,FTK,FLATEXDEGIRO AG NA O.N.,Common stock,EUR,2504808,2021-03-15,15:00,81.5,81.5,81.5,81.5,15,1\nDE000KC01000,KCO,KLOECKNER + CO SE NA O.N.,Common stock,EUR,2504810,2021-03-15,15:00,9.66,9.66,9.655,9.66,1303,5\nDE000KSAG888,SDF,K+S AG NA O.N.,Common stock,EUR,2504812,2021-03-15,15:00,8.794,8.794,8.786,8.788,8982,13\nDE000LED4000,OSR,OSRAM LICHT AG NA O.N.,Common stock,EUR,2504813,2021-03-15,15:00,51.96,51.96,51.96,51.96,632,3\nDE000LEG1110,LEG,LEG IMMOBILIEN AG NA O.N.,Common stock, ...

# %%
data = StringIO(csv_obj)
df = pd.read_csv(data, delimiter=',')
df
# Out:
#                ISIN Mnemonic               SecurityDesc  SecurityType  \
# 0      CA0679011084      ABR         BARRICK GOLD CORP.  Common stock
# 1      DE000A0BVU28     OSP2            USU SOFTWARE AG  Common stock
# 2      DE000A0D6554     NDX1             NORDEX SE O.N.  Common stock
# 3      DE000A0D9PT0      MTX   MTU AERO ENGINES NA O.N.  Common stock
# 4      DE000A0F5UJ7     EXV1  IS.S.EU.600 BANK.U.ETF A.           ETF
# ...             ...      ...                        ...           ...
# 13032  IE00BMC38736     VVSM  VANE.SEMICONDUCTOR UC.ETF           ETF
# 13033  DE000A3H2200      NA9        NAGARRO SE  NA O.N.  Common stock
# 13034  US36467W1099     GS2C           GAMESTOP CORP. A  Common stock
# 13035  DE000A2LQ884      AG1   AUTO1 GROUP SE  INH O.N.  Common stock
# 13036  US92556V1061      VIA         VIATRIS INC.  O.N.  Common stock
#
#       Currency  SecurityID        Date   Time  StartPrice  MaxPrice  MinPrice  \
# 0          EUR     2504196  2021-03-15  15:00      17.060    17.060    17.060
# 1          EUR     2504280  2021-03-15  15:00      26.600    26.600    26.600
# 2          EUR     2504290  2021-03-15  15:00      22.120    22.120    22.120
# 3          EUR     2504297  2021-03-15  15:00     204.300   204.400   204.300
# 4          EUR     2504306  2021-03-15  15:00      12.656    12.662    12.656
# ...        ...         ...         ...    ...         ...       ...       ...
# 13032      EUR     5879481  2021-03-15  15:59      18.500    18.500    18.500
# 13033      EUR     5906903  2021-03-15  15:59      87.200    87.200    87.200
# 13034      EUR     5990151  2021-03-15  15:59     210.500   210.650   210.500
# 13035      EUR     6080964  2021-03-15  15:59      46.790    46.790    46.790
# 13036      EUR     6098375  2021-03-15  15:59      12.000    12.000    12.000
#
#        EndPrice  TradedVolume  NumberOfTrades
# 0        17.060          2000               1
# 1        26.600            70               1
# 2        22.120           119               1
# 3       204.400            98               4
# 4        12.662             5               3
# ...         ...           ...             ...
# 13032    18.500            45               1
# 13033    87.200             5               1
# 13034   210.650           339               3
# 13035    46.790           196               1
# 13036    12.000            18               1
#
# [13037 rows x 14 columns]
